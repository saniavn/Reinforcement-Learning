# %% [markdown]
# <center>
#     COMP4600/5500 - Reinforcement Learning
#
# # Final Project: RL in Action
#
# ### Due: Thursday, December 9th 11:59 pm

# %% [markdown]
# Student Name: Saniya Vahedian Movahed

# %% [markdown]
# **TASK II**
#
# **Scenario for small environment**\
#
# **cells:states**
# **White**: are **walls** which are obstacles and agent will not walk in there\
# **Black**: has a rewraed of **-1**\
# **Red**:**lava** has a reward of **-5**\
# **Green**: **goal** has a reward of **0**\
#
# **Scenario for large environment**\
#
# **cells:states**
# **White**: are **walls** which are obstacles and agent will not walk in there\
# **Black**: has a rewraed of **-1**\
# **Red**:**lava** has a reward of **-5**\
# **Green**: **goal** has a reward of **0**\
# **Blue**: **ice** has rewrad of **0**\. Also, if an agnet walk ther, this cells have stochastic behavior by moving agent by $70%$ probability to one side and by $10%$ toanother directions.
#
# **Actions for both environments **\\
# **RIGHT** Going to the right (next column) \
# **LEFT** Going to the left (previous column)\
# **FORWARD** Going forward (previous row) \
# **BACKWARD** Going backward (next row)
#
#
# **Using Q-learning--parameters**\
#
# **epsilon= 0.5, alphat= 0.1, runs= 50, epoisode= 500**

# %% [markdown]
# ![task2-grid.png](attachment:task2-grid.png)

# %% [markdown]
# ### cumulative rewrads and steps for both environments.

# %% [markdown]
# ![Task2-steps.png](attachment:Task2-steps.png)

# %% [markdown]
# ![task2-rewards.png](attachment:task2-rewards.png)

# %% [markdown]
# ![task2-smallsteps.png](attachment:task2-smallsteps.png)

# %% [markdown]
# ![task2-smallrewrads.png](attachment:task2-smallrewrads.png)

# %% [markdown]
# ![task2-largesteps.png](attachment:task2-largesteps.png)

# %% [markdown]
# ![task2-largerewards.png](attachment:task2-largerewards.png)

# %% [markdown]
# ### Evaluation for 100 total rewards for both small and large environments

# %% [markdown]
# ![Task2-valuationsmall.png](attachment:Task2-valuationsmall.png)

# %% [markdown]
# ![Task2-largeevaluation.png](attachment:Task2-largeevaluation.png)

# %% [markdown]
# **Small environment**
#
# \
# **Standard Deviation =  101.80714437830306 \
#  Minimum Error =  -102.5 \
#  Maximum Error =  -100.0 \
#  Mean Squared Error =  10261.047700000001**
#
# **large environment**
#
# \
# **Standard Deviation =  103.77854481363845 \
#  Minimum Error =  -107.6 \
#  Maximum Error =  -100.0 \
#  Mean Squared Error =  10662.286499999998**
